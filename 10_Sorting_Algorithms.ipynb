# %%
# Bubble Sort
# Time: O(n^2), Space: O(1)

A =  [-5, 3, 2, 1, -3, -3, 7, 2, 2]
    
def bubble_sort(arr):
    n = len(arr)
    flag = True
    
    while flag:
        flag = False
        for i in range(1, n):
            if arr[i-1] > arr[i]: # if i-1 > i then ascending order, if i-1 < i then descending order
                flag = True
                arr[i-1], arr[i] = arr[i], arr[i-1]
                
bubble_sort(A)

A
# Out:
# [-5, -3, -3, 1, 2, 2, 2, 3, 7]

# %%
# Insertion Sort
# Time: O(n^2), Space: O(1)

B =  [-5, 3, 2, 1, -3, -3, 7, 2, 2]

def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        for j in range(i, 0, -1): # start at i and 0 is end(exclusive) and since going down 
            if arr[j-1] > arr[j]:
                arr[j-1], arr[j] = arr[j], arr[j-1]
            else:
                break
            
insertion_sort(B)
B
# Out:
# [-5, -3, -3, 1, 2, 2, 2, 3, 7]

# %%
# Selection Sort
# Time: O(n^2), Space: O(1)

C = [-3, 3, 2, 1, -5, -3, 7, 2, 2]

def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n): # start at i+1 as we made i as the min index
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
        
selection_sort(C)
C
# Out:
# [-5, -3, -3, 1, 2, 2, 2, 3, 7]

# %%
# Merge Sort
# Time: O(n * log n), Space: O(log n)/ O(n)

D = [-5, 3, 2, 1, -3, -3, 7, 2, 2]


def merge_sort(arr):
    n = len(arr)
    
    if n == 1: # no need of n == 0 or as it will cut in half
        return arr
    
    m = len(arr) // 2
    L = arr[:m] # from beginning (excluding m)
    R = arr[m:] # from m till end (including m) 
    
    L = merge_sort(L)
    R = merge_sort(R)
    l, r = 0, 0
    L_len = len(L)
    R_len = len(R)
    
    sorted_arr = [0] * n
    i = 0
    
    while l < L_len and r < R_len: # same as &  
        if L[l] < R[r]:
            sorted_arr[i] = L[l]
            l += 1
        else:
            sorted_arr[i] = R[r]
            r += 1
            
        i += 1
        
    while l < L_len:
        sorted_arr[i] = L[l]
        l += 1
        i += 1
        
    while r < R_len:
        sorted_arr[i] = R[r]
        r += 1
        i += 1
        
    return sorted_arr
    
merge_sort(D)
# Out:
# [-5, 3, 2, 1, -3, -3, 7, 2, 2]

# %%
# Merge Sort
# Time: O(n * log n), Space: O(log n)/ O(n)

E = [-5, 3, 2, 1, -3, -3, 7, 2, 2]

def merge_sort(arr):
    n = len(arr)
    
    if n == 1: 
        return arr
    
    m = len(arr) // 2
    L = arr[:m]
    R = arr[m:]
    
    L = merge_sort(L)
    R = merge_sort(R)
    l, r = 0, 0
    L_len = len(L)
    R_len = len(R)
    
    sorted_arr = [0] * n
    i = 0
    
    while l < L_len and r < R_len:
        if L[l] < R[r]:
            sorted_arr[i] = L[l]
            l += 1
        else:
            sorted_arr[i] = R[r]
            r += 1
            
        i += 1
        
    # while l < L_len:
    #     sorted_arr[i] = L[l]
    #     l += 1
    #     i += 1
        
    # while r < R_len:
    #     sorted_arr[i] = R[r]
    #     r += 1 
    #     i += 1
    
    return sorted_arr

merge_sort(E)
# Out:
# [-5, -3, 0, 0, 0, 0, 0, 0, 0]

# %%
# Quick Sort
# Average Time: O(n log n), Worst Case Time: O(n^2) 
# Space: O(n)

E = [5, 3, 2, 1, -3, -3, 7, 2, 2]

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    
    p = arr[-1] # assuming last element be the PIVOT
    
    L = [x for x in arr[:-1] if x <= p]
    R = [x for x in arr[:-1] if x > p]
    
    L = quick_sort(L)
    R = quick_sort(R)
    
    return L + [p] + R

quick_sort(E)
# Out:
# [-3, -3, 1, 2, 2, 2, 3, 5, 7]

# %%
# Counting Sort
# Time: O(n + k) where k is the range of data

# Note: This can be written with negative arrays, but are sticking to positive arrays,
# so k is the max of the array

# Space: O(k)

F = [5, 3, 2, 1, 3, 3, 7, 2, 2]

def counting_sort(arr):
    n = len(arr)
    maxx = max(arr)
    
    counts = [0] * (maxx + 1)
    
    for x in arr:
        counts[x] += 1
        
    i = 0
    for c in range(maxx + 1):
        while counts[c] > 0:
            arr[i] = c
            i += 1
            counts[c] -= 1
            
counting_sort(F)
F
# Out:
# [1, 2, 2, 2, 3, 3, 3, 5, 7]

# %%
# What we usually do in practice

# Time complexity is O(n log n) from using Tim Sort

G = [-5, 3, 2, 1, -3, -3, 7, 2, 2]

# In place(constant space)
G.sort()
G
# Out:
# [-5, -3, -3, 1, 2, 2, 2, 3, 7]

# %%
# Get new sorted array - O(n) space

H = [-5, 3, 2, 1, -3, -3, 7, 2, 2]

sorted_H = sorted(H)

H, sorted_H
# Out:
# ([-5, 3, 2, 1, -3, -3, 7, 2, 2], [-5, -3, -3, 1, 2, 2, 2, 3, 7])

# %%
# Sort array of tuples

I = [(-5, 3), (2, 2), (-3, -3), (7, 2), (2, 1)] # Intervals Problem

sorted_I = sorted(I, key = lambda t: t[0]) # sorted based on 1st position

sorted_I
# Out:
# [(-5, 3), (-3, -3), (2, 2), (2, 1), (7, 2)]

# %%
# Sort array of tuples

J = [(-5, 3), (2, 2), (-3, -3), (7, 2), (2, 1)] # Intervals Problem

sorted_J = sorted(J, key = lambda t: t[1]) # sorted based on 2nd position

sorted_J
# Out:
# [(-3, -3), (2, 1), (2, 2), (7, 2), (-5, 3)]
