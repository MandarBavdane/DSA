# %%
# Binary Trees

class TreeNode:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
        
    def __str__(self):
        return str(self.val)

# %%
#        1
#    2       3
#  4   5   10

# %%
A = TreeNode(1)
B = TreeNode(2)
C = TreeNode(3)
D = TreeNode(4)
E = TreeNode(5)
F = TreeNode(10)

A.left = B
A.right = C
B.left = D
B.right = E
C.left = F

print(A)
# Out:
# 1

# %%
 # Recursive Pre Order Traversal (DFS) (Node, Left, Right) Time: O(n), Space: O(n)
def pre_order(node):
    if not node:
        return
    
    print(node)
    pre_order(node.left)
    pre_order(node.right)
    
pre_order(A)
# Out:
# 1
# 2
# 4
# 5
# 3
# 10

# %%
# Recursive In Order Traversal (DFS) (Left, Node, Right) Time: O(n), Space: O(n)
def in_order(node):
    if not node:
        return

    in_order(node.left)
    print(node)
    in_order(node.right)
    
in_order(A)
# Out:
# 4
# 2
# 5
# 1
# 10
# 3

# %%
# Recursive Post Order Traversal (DFS) (Left, Right, Node) Time: O(n), Space: O(n)
def post_order(node):
    if not (node):
        return
    
    post_order(node.left)
    post_order(node.right)
    print(node)
    
post_order(A)
# Out:
# 4
# 5
# 2
# 10
# 3
# 1

# %%
# Iterative Pre Order Traversal (DFS) (Node, Left, Right) Time: O(n), Space: O(n)
def pre_order_iterative(node):
    stk = [node] # putting root node on the stack
    
    while stk:
        node = stk.pop()
        print(node)
        
        if node.right: stk.append(node.right)
        if node.left: stk.append(node.left)
        
pre_order_iterative(A)
# Out:
# 1
# 2
# 4
# 5
# 3
# 10

# %%
# Queue usage in Level Order Traversal (BFS) Time: O(n), Space: O(n)
from collections import deque

def level_order(node): # Root node
    q = deque()
    q.append(node)
    
    while q: 
        node = q.popleft()
        print(node)
        
        if node.left: q.append(node.left)
        if node.right: q.append(node.right)
        
level_order(A)
# Out:
# 1
# 2
# 3
# 4
# 5
# 10

# %%
# Check if the value exists (DFS) Time: O(n), Space: O(n)

def search(node, target):
    if not node:
        return False
    
    if node.val == target:
        return True
    
    return search(node.left, target) or search(node.right, target)

search(A, 3)
# Out:
# True

# %%
# Binary Search trees (BSTs)

#           5
#       1       8
#    -1   3   7   9

# %%
A2 = TreeNode(5)
B2 = TreeNode(1)
C2 = TreeNode(8)
D2 = TreeNode(-1)
E2 = TreeNode(3)
F2 = TreeNode(7)
G2 = TreeNode(9)

A2.left, A2.right = B2, C2
B2.left, B2.right = D2, E2
C2.left, C2.right = F2, G2

print(A2)
# Out:
# 5

# %%
in_order(A2)
# Out:
# -1
# 1
# 3
# 5
# 7
# 8
# 9

# %%
# Time: O(log n), Space: O(log n) # assuming it is a balanced tree

def search_bst(node, target):
    if not node:
        return False
    
    if node.val == target:
        return True
    
    if target < node.val: return search_bst(node.left, target)
    else: return search_bst(node.right, target)
    
search_bst(A2, 5)
# Out:
# True
